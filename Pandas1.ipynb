# %%
import numpy as np
import pandas as pd

# %%
#read and store csv file into a variable
data=pd.read_csv('Amazon 3 Final.csv')
data
# Out:
#             Order ID  Order Date   Ship Date   Status   Customer Name  \
# 0     CA-2013-138688  06/13/2013  06/17/2013  On time   DarrinVanHuff
# 1     CA-2011-115812  06-09-2011  06/14/2011    Delay  BrosinaHoffman
# 2     CA-2011-115812  06-09-2011  06/14/2011    Delay  BrosinaHoffman
# 3     CA-2011-115812  06-09-2011  06/14/2011    Delay  BrosinaHoffman
# 4     CA-2011-115812  06-09-2011  06/14/2011    Delay  BrosinaHoffman
# ...              ...         ...         ...      ...             ...
# 3198  CA-2013-125794  09/30/2013  10-04-2013  On time     MarisLaWare
# 3199  CA-2014-121258  02/27/2014  03-04-2014    Delay      DaveBrooks
# 3200  CA-2014-121258  02/27/2014  03-04-2014    Delay      DaveBrooks
# 3201  CA-2014-121258  02/27/2014  03-04-2014    Delay      DaveBrooks
# 3202  CA-2014-119914  05-05-2014  05-10-2014    Delay     ChrisCortes
#
#             Country         City       State     Category  \
# 0     United States  Los Angeles  California       Labels
# ...

# %%
#it prints the type of data (file)
type(data)
# Out:
# pandas.core.frame.DataFrame

# %%
#it prints the pre-view of data(1st 5 rows with label)
data.head()
# Out:
#          Order ID  Order Date   Ship Date   Status   Customer Name  \
# 0  CA-2013-138688  06/13/2013  06/17/2013  On time   DarrinVanHuff
# 1  CA-2011-115812  06-09-2011  06/14/2011    Delay  BrosinaHoffman
# 2  CA-2011-115812  06-09-2011  06/14/2011    Delay  BrosinaHoffman
# 3  CA-2011-115812  06-09-2011  06/14/2011    Delay  BrosinaHoffman
# 4  CA-2011-115812  06-09-2011  06/14/2011    Delay  BrosinaHoffman
#
#          Country         City       State     Category  \
# 0  United States  Los Angeles  California       Labels
# 1  United States  Los Angeles  California  Furnishings
# 2  United States  Los Angeles  California          Art
# 3  United States  Los Angeles  California       Phones
# 4  United States  Los Angeles  California      Binders
#
#                                         Product Name    Sales  Quantity  \
# 0  Self-Adhesive Address Labels for Typewriters b...   14.620         2
# 1  Eldon Expressions Wood and Plastic Desk Access...   48.860         7
# ...

# %%
#it prints the pre-view of data(last 5 rows with label)
data.tail()
# Out:
#             Order ID  Order Date   Ship Date   Status Customer Name  \
# 3198  CA-2013-125794  09/30/2013  10-04-2013  On time   MarisLaWare
# 3199  CA-2014-121258  02/27/2014  03-04-2014    Delay    DaveBrooks
# 3200  CA-2014-121258  02/27/2014  03-04-2014    Delay    DaveBrooks
# 3201  CA-2014-121258  02/27/2014  03-04-2014    Delay    DaveBrooks
# 3202  CA-2014-119914  05-05-2014  05-10-2014    Delay   ChrisCortes
#
#             Country         City       State     Category  \
# 3198  United States  Los Angeles  California  Accessories
# 3199  United States   Costa Mesa  California  Furnishings
# 3200  United States   Costa Mesa  California       Phones
# 3201  United States   Costa Mesa  California        Paper
# 3202  United States  Westminster  California   Appliances
#
#                                            Product Name    Sales  Quantity  \
# 3198  Memorex Mini Travel Drive 64 GB USB 2.0 Flash ...   36.240         1
# ...

# %%
#specifing the number of rows that should be displayed
data.head(10)
# Out:
#          Order ID  Order Date   Ship Date   Status   Customer Name  \
# 0  CA-2013-138688  06/13/2013  06/17/2013  On time   DarrinVanHuff
# 1  CA-2011-115812  06-09-2011  06/14/2011    Delay  BrosinaHoffman
# 2  CA-2011-115812  06-09-2011  06/14/2011    Delay  BrosinaHoffman
# 3  CA-2011-115812  06-09-2011  06/14/2011    Delay  BrosinaHoffman
# 4  CA-2011-115812  06-09-2011  06/14/2011    Delay  BrosinaHoffman
# 5  CA-2011-115812  06-09-2011  06/14/2011    Delay  BrosinaHoffman
# 6  CA-2011-115812  06-09-2011  06/14/2011    Delay  BrosinaHoffman
# 7  CA-2011-115812  06-09-2011  06/14/2011    Delay  BrosinaHoffman
# 8  CA-2013-161389  12-06-2013  12-11-2013    Delay     IreneMaddox
# 9  CA-2011-167164  05/13/2011  05/15/2011  On time  AlejandroGrove
#
#          Country         City       State     Category  \
# 0  United States  Los Angeles  California       Labels
# 1  United States  Los Angeles  California  Furnishings
# 2  United States  Los Angeles  California          Art
# ...

# %%
#shape of data
data.shape
# Out:
# (3203, 13)

# %%
#rows
data.shape[0]
# Out:
# 3203

# %%
#columns
data.shape[1]
# Out:
# 13

# %%
#information od the data(labels and type of data...)
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3203 entries, 0 to 3202
# Data columns (total 13 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Order ID       3203 non-null   object
#  1   Order Date     3203 non-null   object
#  2   Ship Date      3203 non-null   object
#  3   Status         3203 non-null   object
#  4   Customer Name  3203 non-null   object
#  5   Country        3203 non-null   object
#  6   City           3203 non-null   object
#  7   State          3203 non-null   object
#  8   Category       3203 non-null   object
#  9   Product Name   3203 non-null   object
#  10  Sales          3203 non-null   float64
#  11  Quantity       3203 non-null   int64
#  12  Profit         3203 non-null   float64
# dtypes: float64(2), int64(1), object(10)
# memory usage: 325.4+ KB

# %%
#data summary of mathematics
data.describe()
# Out:
#               Sales     Quantity       Profit
# count   3203.000000  3203.000000  3203.000000
# mean     226.493233     3.828910    33.849032
# std      524.876877     2.260947   174.109081
# min        0.990000     1.000000 -3399.980000
# 25%       19.440000     2.000000     3.852000
# 50%       60.840000     3.000000    11.166400
# 75%      215.809000     5.000000    33.000400
# max    13999.960000    14.000000  6719.980800

# %%
#names of all the customers
data['Customer Name']
# Out:
# 0        DarrinVanHuff
# 1       BrosinaHoffman
# 2       BrosinaHoffman
# 3       BrosinaHoffman
# 4       BrosinaHoffman
#              ...
# 3198       MarisLaWare
# 3199        DaveBrooks
# 3200        DaveBrooks
# 3201        DaveBrooks
# 3202       ChrisCortes
# Name: Customer Name, Length: 3203, dtype: object

# %%
#type of data
type(data['Customer Name'])
# Out:
# pandas.core.series.Series

# %%
#customer name and state
data[['Customer Name','State']]
# Out:
#        Customer Name       State
# 0      DarrinVanHuff  California
# 1     BrosinaHoffman  California
# 2     BrosinaHoffman  California
# 3     BrosinaHoffman  California
# 4     BrosinaHoffman  California
# ...              ...         ...
# 3198     MarisLaWare  California
# 3199      DaveBrooks  California
# 3200      DaveBrooks  California
# 3201      DaveBrooks  California
# 3202     ChrisCortes  California
#
# [3203 rows x 2 columns]

# %%
type(data[['Customer Name','State']])
# Out:
# pandas.core.frame.DataFrame

# %%
#shape of data
data[['Customer Name','State']].shape
# Out:
# (3203, 2)

# %%
#indexing
data.iloc[0]
# Out:
# Order ID                                            CA-2013-138688
# Order Date                                              06/13/2013
# Ship Date                                               06/17/2013
# Status                                                     On time
# Customer Name                                        DarrinVanHuff
# Country                                              United States
# City                                                   Los Angeles
# State                                                   California
# Category                                                    Labels
# Product Name     Self-Adhesive Address Labels for Typewriters b...
# Sales                                                        14.62
# Quantity                                                         2
# Profit                                                      6.8714
# Name: 0, dtype: object

# %%
#slicling
data.iloc[2:15]
# Out:
#           Order ID  Order Date   Ship Date   Status      Customer Name  \
# 2   CA-2011-115812  06-09-2011  06/14/2011    Delay     BrosinaHoffman
# 3   CA-2011-115812  06-09-2011  06/14/2011    Delay     BrosinaHoffman
# 4   CA-2011-115812  06-09-2011  06/14/2011    Delay     BrosinaHoffman
# 5   CA-2011-115812  06-09-2011  06/14/2011    Delay     BrosinaHoffman
# 6   CA-2011-115812  06-09-2011  06/14/2011    Delay     BrosinaHoffman
# 7   CA-2011-115812  06-09-2011  06/14/2011    Delay     BrosinaHoffman
# 8   CA-2013-161389  12-06-2013  12-11-2013    Delay        IreneMaddox
# 9   CA-2011-167164  05/13/2011  05/15/2011  On time     AlejandroGrove
# 10  CA-2011-143336  08/27/2011  09-01-2011    Delay  ZuschussDonatelli
# 11  CA-2011-143336  08/27/2011  09-01-2011    Delay  ZuschussDonatelli
# 12  CA-2011-143336  08/27/2011  09-01-2011    Delay  ZuschussDonatelli
# 13  CA-2012-106320  09/25/2012  09/30/2012    Delay         EmilyBurns
# ...

# %%
#iteration
data.iloc[1:11:2]
# Out:
#          Order ID  Order Date   Ship Date   Status   Customer Name  \
# 1  CA-2011-115812  06-09-2011  06/14/2011    Delay  BrosinaHoffman
# 3  CA-2011-115812  06-09-2011  06/14/2011    Delay  BrosinaHoffman
# 5  CA-2011-115812  06-09-2011  06/14/2011    Delay  BrosinaHoffman
# 7  CA-2011-115812  06-09-2011  06/14/2011    Delay  BrosinaHoffman
# 9  CA-2011-167164  05/13/2011  05/15/2011  On time  AlejandroGrove
#
#          Country         City       State     Category  \
# 1  United States  Los Angeles  California  Furnishings
# 3  United States  Los Angeles  California       Phones
# 5  United States  Los Angeles  California   Appliances
# 7  United States  Los Angeles  California       Phones
# 9  United States  West Jordan        Utah      Storage
#
#                                         Product Name    Sales  Quantity  \
# 1  Eldon Expressions Wood and Plastic Desk Access...   48.860         7
# 3                     Mitel 5320 IP Phone VoIP phone  907.152         4
# ...

# %%
data.iloc[[1,3,8]]
# Out:
#          Order ID  Order Date   Ship Date Status   Customer Name  \
# 1  CA-2011-115812  06-09-2011  06/14/2011  Delay  BrosinaHoffman
# 3  CA-2011-115812  06-09-2011  06/14/2011  Delay  BrosinaHoffman
# 8  CA-2013-161389  12-06-2013  12-11-2013  Delay     IreneMaddox
#
#          Country         City       State     Category  \
# 1  United States  Los Angeles  California  Furnishings
# 3  United States  Los Angeles  California       Phones
# 8  United States      Seattle  Washington      Binders
#
#                                         Product Name    Sales  Quantity  \
# 1  Eldon Expressions Wood and Plastic Desk Access...   48.860         7
# 3                     Mitel 5320 IP Phone VoIP phone  907.152         4
# 8        Fellowes PB200 Plastic Comb Binding Machine  407.976         3
#
#      Profit
# 1   14.1694
# 3   90.7152
# 8  132.5922

# %%
#fancy indexing
data.iloc[:,[4,5,7]]
# Out:
#        Customer Name        Country       State
# 0      DarrinVanHuff  United States  California
# 1     BrosinaHoffman  United States  California
# 2     BrosinaHoffman  United States  California
# 3     BrosinaHoffman  United States  California
# 4     BrosinaHoffman  United States  California
# ...              ...            ...         ...
# 3198     MarisLaWare  United States  California
# 3199      DaveBrooks  United States  California
# 3200      DaveBrooks  United States  California
# 3201      DaveBrooks  United States  California
# 3202     ChrisCortes  United States  California
#
# [3203 rows x 3 columns]

# %%
#los angeles city data
data['City']=='Los Angeles'
# Out:
# 0        True
# 1        True
# 2        True
# 3        True
# 4        True
#         ...
# 3198     True
# 3199    False
# 3200    False
# 3201    False
# 3202    False
# Name: City, Length: 3203, dtype: bool

# %%
#masking
mask=data['City']=='Los Angeles'
data[mask]
# Out:
#             Order ID  Order Date   Ship Date   Status   Customer Name  \
# 0     CA-2013-138688  06/13/2013  06/17/2013  On time   DarrinVanHuff
# 1     CA-2011-115812  06-09-2011  06/14/2011    Delay  BrosinaHoffman
# 2     CA-2011-115812  06-09-2011  06/14/2011    Delay  BrosinaHoffman
# 3     CA-2011-115812  06-09-2011  06/14/2011    Delay  BrosinaHoffman
# 4     CA-2011-115812  06-09-2011  06/14/2011    Delay  BrosinaHoffman
# ...              ...         ...         ...      ...             ...
# 3194  US-2013-103674  12-07-2013  12-11-2013  On time       AnnePryor
# 3195  US-2013-103674  12-07-2013  12-11-2013  On time       AnnePryor
# 3196  US-2013-103674  12-07-2013  12-11-2013  On time       AnnePryor
# 3197  US-2013-103674  12-07-2013  12-11-2013  On time       AnnePryor
# 3198  CA-2013-125794  09/30/2013  10-04-2013  On time     MarisLaWare
#
#             Country         City       State     Category  \
# 0     United States  Los Angeles  California       Labels
# ...

# %%
data[mask].shape
# Out:
# (747, 13)

# %%
#funtion to find count
def get_city_count(City):
    mask=data['City']==City
    return data[mask].shape[0]

# %%
get_city_count('Costa Mesa')
# Out:
# 11

# %%
#integrating 2 conditions with '&'
mask1=data['City']=='Costa Mesa'
mask2=data['Ship Date']>'10-04-2013'
data[mask1&mask2]
# Out:
#             Order ID  Order Date   Ship Date   Status Customer Name  \
# 860   CA-2014-144827  12/22/2014  12/28/2014    Delay   SanjitEngle
# 1994  CA-2012-114048  12/14/2012  12/18/2012  On time  EricHoffmann
#
#             Country        City       State     Category  \
# 860   United States  Costa Mesa  California      Storage
# 1994  United States  Costa Mesa  California  Furnishings
#
#                           Product Name   Sales  Quantity   Profit
# 860   Fellowes Mobile File Cart, Black  124.36         2  33.5772
# 1994                           Staples   29.22         3  12.8568

# %%
data[mask1&mask2].shape[0]
# Out:
# 2

# %%
#value_couts- for categorial data
data['Product Name'].value_counts()
# Out:
# Product Name
# Staples                                                 60
# Avery Non-Stick Binders                                  8
# Bretford Rectangular Conference Table Tops               7
# Global Troy Executive Leather Low-Back Tilter            7
# SAFCO Arco Folding Chair                                 7
#                                                         ..
# Avery 505                                                1
# RCA ViSYS 25423RE1 Corded phone                          1
# Master Giant Foot Doorstop, Safety Yellow                1
# Bush Westfield Collection Bookcases, Fully Assembled     1
# Avaya 5410 Digital phone                                 1
# Name: count, Length: 1494, dtype: int64

# %%
#ploting function
import matplotlib.pyplot as plt

# %%
#barh=horizontal bar plot
data['Profit'].value_counts().plot(kind='barh')
# Out:
# <Axes: ylabel='Profit'>

# %%
#pie chart
data['Category'].value_counts().plot(kind='pie')
# Out:
# <Axes: ylabel='count'>

# %%
data['Sales'].value_counts().plot(kind='hist')
# Out:
# <Axes: ylabel='Frequency'>

# %%
#series in pandas
myseries=data['Category'].value_counts()
myseries
# Out:
# Category
# Binders        471
# Paper          450
# Furnishings    304
# Phones         277
# Storage        266
# Accessories    258
# Art            250
# Chairs         207
# Appliances     136
# Labels         116
# Tables         116
# Bookcases       80
# Fasteners       72
# Supplies        69
# Envelopes       67
# Machines        39
# Copiers         25
# Name: count, dtype: int64

# %%
type(myseries)
# Out:
# pandas.core.series.Series

# %%
myseries['Appliances']
# Out:
# 136

# %%
x=data['Sales'].value_counts()*data['Quantity'].value_counts()
x
# Out:
# 0.990       NaN
# 1.000       NaN
# 1.080       NaN
# 1.188       NaN
# 1.344       NaN
#              ..
# 4799.984    NaN
# 4912.590    NaN
# 5083.960    NaN
# 8187.650    NaN
# 13999.960   NaN
# Name: count, Length: 2360, dtype: float64

# %%
type(x)
# Out:
# pandas.core.series.Series

# %%
#sorting values
x.sort_values()
# Out:
# 8.000         87.0
# 5.000        405.0
# 0.990          NaN
# 1.000          NaN
# 1.080          NaN
#              ...
# 4799.984       NaN
# 4912.590       NaN
# 5083.960       NaN
# 8187.650       NaN
# 13999.960      NaN
# Name: count, Length: 2360, dtype: float64

# %%
#sorting in descending order
y=x.sort_values(ascending=False)
y
# Out:
# 5.000        405.0
# 8.000         87.0
# 0.990          NaN
# 1.000          NaN
# 1.080          NaN
#              ...
# 4799.984       NaN
# 4912.590       NaN
# 5083.960       NaN
# 8187.650       NaN
# 13999.960      NaN
# Name: count, Length: 2360, dtype: float64

# %%
y.head(10)
# Out:
# 5.000    405.0
# 8.000     87.0
# 0.990      NaN
# 1.000      NaN
# 1.080      NaN
# 1.188      NaN
# 1.344      NaN
# 1.408      NaN
# 1.440      NaN
# 1.810      NaN
# Name: count, dtype: float64

# %%
#sorting in dataframes
data.sort_values('City')
# Out:
#             Order ID  Order Date   Ship Date   Status   Customer Name  \
# 994   CA-2014-106859  03/14/2014  03/19/2014    Delay  BenjaminFarhat
# 992   CA-2014-106859  03/14/2014  03/19/2014    Delay  BenjaminFarhat
# 995   CA-2014-106859  03/14/2014  03/19/2014    Delay  BenjaminFarhat
# 996   CA-2014-106859  03/14/2014  03/19/2014    Delay  BenjaminFarhat
# 2976  US-2011-134054  10-10-2011  10-10-2011  On time       FredChung
# ...              ...         ...         ...      ...             ...
# 1079  CA-2012-112011  08/13/2012  08/20/2012    Delay    OdellaNelson
# 2628  CA-2013-106621  09/30/2013  10-02-2013  On time     DarioMedina
# 2362  CA-2013-108224  05/15/2013  05/15/2013  On time    TiffanyHouse
# 1537  CA-2013-134222  07-11-2013  07-12-2013  On time    NickZandusky
# 2363  CA-2014-159282  10/17/2014  10/22/2014    Delay      GaryHansen
#
#             Country         City       State     Category  \
# 994   United States  Albuquerque  New Mexico  Accessories
# ...

# %%
#sort customer name in desending order
data.sort_values('Customer Name',ascending=False)
# Out:
#             Order ID  Order Date   Ship Date   Status      Customer Name  \
# 11    CA-2011-143336  08/27/2011  09-01-2011    Delay  ZuschussDonatelli
# 12    CA-2011-143336  08/27/2011  09-01-2011    Delay  ZuschussDonatelli
# 2701  CA-2014-141481  06-12-2014  06/15/2014  On time  ZuschussDonatelli
# 10    CA-2011-143336  08/27/2011  09-01-2011    Delay  ZuschussDonatelli
# 195   US-2013-156986  03/21/2013  03/25/2013  On time    ZuschussCarroll
# ...              ...         ...         ...      ...                ...
# 3103  CA-2012-130113  12/27/2012  12/31/2012  On time       AaronHawkins
# 1714  CA-2011-113768  05/13/2011  05/19/2011    Delay       AaronHawkins
# 1594  CA-2011-156587  03-07-2011  03-08-2011  On time       AaronBergman
# 1596  CA-2011-156587  03-07-2011  03-08-2011  On time       AaronBergman
# 1595  CA-2011-156587  03-07-2011  03-08-2011  On time       AaronBergman
#
#             Country           City       State    Category  \
# ...

# %%
#data.sort_values('City',inplace=True)
# It is used tomake the changes permanent but you should not do that, we may miss the original data

# %%
data.sort_values(['City','Ship Date'])
# Out:
#             Order ID  Order Date   Ship Date   Status   Customer Name  \
# 2636  CA-2014-122798  12/29/2014  01-02-2015  On time  SusanVittorini
# 2637  CA-2014-122798  12/29/2014  01-02-2015  On time  SusanVittorini
# 1356  CA-2011-152345  12/29/2011  01-03-2012    Delay         ShuiTom
# 1357  CA-2011-152345  12/29/2011  01-03-2012    Delay         ShuiTom
# 992   CA-2014-106859  03/14/2014  03/19/2014    Delay  BenjaminFarhat
# ...              ...         ...         ...      ...             ...
# 1079  CA-2012-112011  08/13/2012  08/20/2012    Delay    OdellaNelson
# 2362  CA-2013-108224  05/15/2013  05/15/2013  On time    TiffanyHouse
# 1537  CA-2013-134222  07-11-2013  07-12-2013  On time    NickZandusky
# 2628  CA-2013-106621  09/30/2013  10-02-2013  On time     DarioMedina
# 2363  CA-2014-159282  10/17/2014  10/22/2014    Delay      GaryHansen
#
#             Country         City       State     Category  \
# 2636  United States  Albuquerque  New Mexico      Storage
# ...

# %%
data.sort_values(['City','Ship Date'],ascending=[True,False])
# Out:
#             Order ID  Order Date   Ship Date   Status     Customer Name  \
# 769   CA-2014-168655  10/13/2014  10/19/2014    Delay  MichelleLonsdale
# 770   CA-2014-168655  10/13/2014  10/19/2014    Delay  MichelleLonsdale
# 2976  US-2011-134054  10-10-2011  10-10-2011  On time         FredChung
# 1385  US-2014-103226  09/23/2014  09/29/2014    Delay       DavidWiener
# 2733  CA-2011-100881  03/28/2011  04-01-2011  On time      DanielRaglin
# ...              ...         ...         ...      ...               ...
# 1079  CA-2012-112011  08/13/2012  08/20/2012    Delay      OdellaNelson
# 2363  CA-2014-159282  10/17/2014  10/22/2014    Delay        GaryHansen
# 2628  CA-2013-106621  09/30/2013  10-02-2013  On time       DarioMedina
# 1537  CA-2013-134222  07-11-2013  07-12-2013  On time      NickZandusky
# 2362  CA-2013-108224  05/15/2013  05/15/2013  On time      TiffanyHouse
#
#             Country         City       State     Category  \
# ...

# %%
#drop duplicates- it is used to remove duplicate values in the data
data.drop_duplicates(subset=['City'])
# Out:
#             Order ID  Order Date   Ship Date   Status      Customer Name  \
# 0     CA-2013-138688  06/13/2013  06/17/2013  On time      DarrinVanHuff
# 8     CA-2013-161389  12-06-2013  12-11-2013    Delay        IreneMaddox
# 9     CA-2011-167164  05/13/2011  05/15/2011  On time     AlejandroGrove
# 10    CA-2011-143336  08/27/2011  09-01-2011    Delay  ZuschussDonatelli
# 13    CA-2012-106320  09/25/2012  09/30/2012    Delay         EmilyBurns
# ...              ...         ...         ...      ...                ...
# 2823  CA-2013-116911  09/16/2013  09/21/2013    Delay    JustinDeggeller
# 3098  CA-2013-126270  04/24/2013  04/28/2013  On time        ArtFerguson
# 3100  US-2014-140312  11/14/2014  11/20/2014    Delay        KenLonsdale
# 3115  CA-2013-105291  10/31/2013  11-05-2013    Delay        SusanPistek
# 3140  CA-2014-137918  09/30/2014  10-07-2014    Delay       JoeKamberova
#
#             Country             City       State   Category  \
# ...

# %%
data.drop_duplicates(subset=['Customer Name'])
# Out:
#             Order ID  Order Date   Ship Date   Status      Customer Name  \
# 0     CA-2013-138688  06/13/2013  06/17/2013  On time      DarrinVanHuff
# 1     CA-2011-115812  06-09-2011  06/14/2011    Delay     BrosinaHoffman
# 8     CA-2013-161389  12-06-2013  12-11-2013    Delay        IreneMaddox
# 9     CA-2011-167164  05/13/2011  05/15/2011  On time     AlejandroGrove
# 10    CA-2011-143336  08/27/2011  09-01-2011    Delay  ZuschussDonatelli
# ...              ...         ...         ...      ...                ...
# 3141  US-2011-139640  11-07-2011  11-11-2011  On time      TroyBlackwell
# 3148  US-2013-125402  09/26/2013  10-02-2013    Delay          DanLawera
# 3165  CA-2014-117646  08/22/2014  08/26/2014  On time          SungChung
# 3183  CA-2011-143371  12/28/2011  01-03-2012    Delay       MaribethDona
# 3191  US-2013-103674  12-07-2013  12-11-2013  On time          AnnePryor
#
#             Country           City       State     Category  \
# ...

# %%
data.drop_duplicates(subset=['City'],keep='last')
# Out:
#             Order ID  Order Date   Ship Date   Status   Customer Name  \
# 66    CA-2014-108329  12-10-2014  12/15/2014    Delay  LaurelElliston
# 92    CA-2013-142902  09/13/2013  09/15/2013  On time     BenPeterman
# 101   CA-2012-128167  06/22/2012  06/26/2012  On time     KenLonsdale
# 248   CA-2012-101910  11/27/2012  12-03-2012    Delay      CarlosDaly
# 302   CA-2012-126445  08/27/2012  08/31/2012  On time        RyanAkin
# ...              ...         ...         ...      ...             ...
# 3185  CA-2012-145415  04-12-2012  04/17/2012    Delay   RobertDilbeck
# 3190  CA-2014-137421  10-07-2014  10-12-2014    Delay    AshleyJarboe
# 3198  CA-2013-125794  09/30/2013  10-04-2013  On time     MarisLaWare
# 3201  CA-2014-121258  02/27/2014  03-04-2014    Delay      DaveBrooks
# 3202  CA-2014-119914  05-05-2014  05-10-2014    Delay     ChrisCortes
#
#             Country           City       State     Category  \
# 66    United States       Whittier  California       Phones
# ...

# %%
data.drop_duplicates(subset=['Customer Name']).shape
# Out:
# (686, 13)

# %%
data.drop_duplicates(subset=['City','Customer Name'])
# Out:
#             Order ID  Order Date   Ship Date   Status      Customer Name  \
# 0     CA-2013-138688  06/13/2013  06/17/2013  On time      DarrinVanHuff
# 1     CA-2011-115812  06-09-2011  06/14/2011    Delay     BrosinaHoffman
# 8     CA-2013-161389  12-06-2013  12-11-2013    Delay        IreneMaddox
# 9     CA-2011-167164  05/13/2011  05/15/2011  On time     AlejandroGrove
# 10    CA-2011-143336  08/27/2011  09-01-2011    Delay  ZuschussDonatelli
# ...              ...         ...         ...      ...                ...
# 3190  CA-2014-137421  10-07-2014  10-12-2014    Delay       AshleyJarboe
# 3191  US-2013-103674  12-07-2013  12-11-2013  On time          AnnePryor
# 3198  CA-2013-125794  09/30/2013  10-04-2013  On time        MarisLaWare
# 3199  CA-2014-121258  02/27/2014  03-04-2014    Delay         DaveBrooks
# 3202  CA-2014-119914  05-05-2014  05-10-2014    Delay        ChrisCortes
#
#             Country           City       State     Category  \
# ...

# %%
data.drop_duplicates(subset=['City','Customer Name']).shape
# Out:
# (1464, 13)

# %%
data.drop_duplicates(subset=['City','Customer Name'])
